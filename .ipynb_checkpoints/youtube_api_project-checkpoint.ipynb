# %% [markdown]
# ### Extracting Youtube data usin API

# %%
pip install google-api-python-client==2.33.0
# Out:
# Requirement already satisfied: google-api-python-client==2.33.0 in c:\users\tanvi\anaconda3\lib\site-packages (2.33.0)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in c:\users\tanvi\anaconda3\lib\site-packages (from google-api-python-client==2.33.0) (0.1.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.21.0 in c:\users\tanvi\anaconda3\lib\site-packages (from google-api-python-client==2.33.0) (2.3.2)
# Requirement already satisfied: uritemplate<5,>=3.0.0 in c:\users\tanvi\anaconda3\lib\site-packages (from google-api-python-client==2.33.0) (4.1.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.16.0 in c:\users\tanvi\anaconda3\lib\site-packages (from google-api-python-client==2.33.0) (2.3.3)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in c:\users\tanvi\anaconda3\lib\site-packages (from google-api-python-client==2.33.0) (0.20.2)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in c:\users\tanvi\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client==2.33.0) (1.54.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\tanvi\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client==2.33.0) (2.26.0)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\tanvi\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client==2.33.0) (58.0.4)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\tanvi\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client==2.33.0) (3.19.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\tanvi\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client==2.33.0) (4.2.4)
# Requirement already satisfied: six>=1.9.0 in c:\users\tanvi\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client==2.33.0) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\tanvi\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client==2.33.0) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\tanvi\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client==2.33.0) (0.2.8)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\tanvi\anaconda3\lib\site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client==2.33.0) (3.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\tanvi\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.16.0->google-api-python-client==2.33.0) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\tanvi\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client==2.33.0) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tanvi\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client==2.33.0) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tanvi\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client==2.33.0) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\tanvi\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client==2.33.0) (2.0.4)

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
apikey='AIzaSyAvDyM4PVSaEWGheInZyvD7JWuWttBHqfg'

#particular channel id

#channel_id='UCKQdc0-Targ4nDIAUrlfKiA'

youtube=build('youtube', 'v3', developerKey=apikey)

# %% [markdown]
# ### Function to get channel statistics

# %%
def channel_stat(youtube, channel_id):
    request=youtube.channels().list(
    part='snippet,contentDetails,statistics',
    id=channel_id)

    response=request.execute()
    return response

# %%
channel_stat(youtube, channel_id)
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'dE4kXt-uH3AinG6sbhZtrKlUwc8',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '9AEIUNF6HEe122Z-e2bcVcGstqg',
#    'id': 'UCKQdc0-Targ4nDIAUrlfKiA',
#    'snippet': {'title': 'Python Simplified',
#     'description': "Hi everyone! My name is Mariya and I'm a Python Developer from Vancouver, British Columbia.\nI film simple programming tutorials about Computer Science Concepts, GUI Applications, Machine Learning and Artificial Intelligence, Automation and Web Scraping, Data Science and even Math! 🤓\nI'm here to help you with your programming journey (in particular - your Python programming journey 😉) and show you how many beautiful and powerful things we can do with code! 💪💪💪\n",
#     'customUrl': 'pythonsimplified',
#     'publishedAt': '2019-01-25T00:48:09Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRnaDX0HUp3EyfaHq8VwC6iDWJpB3o82DqgEwCmeg=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRnaDX0HUp3EyfaHq8VwC6iDWJpB3o82DqgEwCmeg=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRnaDX0HUp3EyfaHq8VwC6iDWJpB3o82DqgEwCmeg=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'Python Simplified',
#      'description': "Hi everyone! My name is Mariya and I'm a Python Developer from Vancouver, British Columbia.\nI film simple programming tutorials about Computer Science Concepts, GUI Applications, Machine Learning and Artificial Intelligence, Automation and Web Scraping, Data Science and even Math! 🤓\nI'm here to help you with your programming journey (in particular - your Python programming journey 😉) and show you how many beautiful and powerful things we can do with code! 💪💪💪\n"},
#     'country': 'CA'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUKQdc0-Targ4nDIAUrlfKiA'}},
#    'statistics': {'viewCount': '1936899',
#     'subscriberCount': '65000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '64'}}]}

# %%
### Function to get channel details
def channel_details(youtube, channel_id):
    request=youtube.channels().list(
    part='snippet,contentDetails,statistics',
    id=channel_id)
    response=request.execute()
    data=dict(Channel_name=response['items'][0]['snippet']['title'],
              Subscribers=response['items'][0]['statistics']['subscriberCount'],
              Views=response['items'][0]['statistics']['viewCount'],
              Total_videos=response['items'][0]['statistics']['videoCount']
             )
    
    return data

# %%
channel_details(youtube, channel_id)
# Out:
# {'Channel_name': 'Python Simplified',
#  'Subscribers': '65000',
#  'Views': '1936899',
#  'Total_videos': '64'}

# %%
# for multiple channel
channel_ids=['UCKQdc0-Targ4nDIAUrlfKiA',# simplyfied python
            'UCLLw7jmFsvfIVaUFsLs8mlQ', #Luke barrouse
            'UC7cs8q-gJRlGwj4A8OmCmXg',#Alex the analyst
            'UCiT9RITQ9PW6BhXK0y2jaeg', # Ken jee
            'UC2UXDak6o7rBm23k3Vv5dww', # Tina huang
            ]

# %%
#functuion for all channels
def all_channel_stat(youtube, channel_ids):
    request=youtube.channels().list(
    part='snippet,contentDetails,statistics',
    id=','.join(channel_ids))

    response=request.execute()
    return response

# %%
all_channel_stat(youtube, channel_ids)
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'dOUZ7RaOEwWDw0kQGOmn4jG9bDY',
#  'pageInfo': {'totalResults': 5, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'k_-JF7F85AsSu0IVuPNCEsoYzoU',
#    'id': 'UC7cs8q-gJRlGwj4A8OmCmXg',
#    'snippet': {'title': 'Alex The Analyst',
#     'description': 'My name is Alex Freberg and on this channel I will going over everything you need to know to become a Data Analyst. If you are wanting to make a career change or learn the skills needed to become a Data Analyst, be sure to subscribe to stay up to date on all my latest content.\n\nYou can find me on LinkedIn at:\nhttps://www.linkedin.com/in/alex-freberg/\n\nDiscord Channel:\nhttps://discord.gg/rxZUjNvRzR\n\n1 on 1 Coaching/Support the Channel:\nhttps://www.patreon.com/AlexTheAnalyst',
#     'customUrl': 'alextheanalyst',
#     'publishedAt': '2020-01-08T05:04:24.970712Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRv2w0F9QoCnR_5XvTekeAYEiUuFQW-u6yWN94h=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRv2w0F9QoCnR_5XvTekeAYEiUuFQW-u6yWN94h=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRv2w0F9QoCnR_5XvTekeAYEiUuFQW-u6yWN94h=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'Alex The Analyst',
#      'description': 'My name is Alex Freberg and on this channel I will going over everything you need to know to become a Data Analyst. If you are wanting to make a career change or learn the skills needed to become a Data Analyst, be sure to subscribe to stay up to date on all my latest content.\n\nYou can find me on LinkedIn at:\nhttps://www.linkedin.com/in/alex-freberg/\n\nDiscord Channel:\nhttps://discord.gg/rxZUjNvRzR\n\n1 on 1 Coaching/Support the Channel:\nhttps://www.patreon.com/AlexTheAnalyst'},
#     'country': 'US'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UU7cs8q-gJRlGwj4A8OmCmXg'}},
#    'statistics': {'viewCount': '5373565',
#     'subscriberCount': '144000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '121'}},
#   {'kind': 'youtube#channel',
#    'etag': '9AEIUNF6HEe122Z-e2bcVcGstqg',
#    'id': 'UCKQdc0-Targ4nDIAUrlfKiA',
#    'snippet': {'title': 'Python Simplified',
#     'description': "Hi everyone! My name is Mariya and I'm a Python Developer from Vancouver, British Columbia.\nI film simple programming tutorials about Computer Science Concepts, GUI Applications, Machine Learning and Artificial Intelligence, Automation and Web Scraping, Data Science and even Math! 🤓\nI'm here to help you with your programming journey (in particular - your Python programming journey 😉) and show you how many beautiful and powerful things we can do with code! 💪💪💪\n",
#     'customUrl': 'pythonsimplified',
#     'publishedAt': '2019-01-25T00:48:09Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRnaDX0HUp3EyfaHq8VwC6iDWJpB3o82DqgEwCmeg=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRnaDX0HUp3EyfaHq8VwC6iDWJpB3o82DqgEwCmeg=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRnaDX0HUp3EyfaHq8VwC6iDWJpB3o82DqgEwCmeg=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'Python Simplified',
#      'description': "Hi everyone! My name is Mariya and I'm a Python Developer from Vancouver, British Columbia.\nI film simple programming tutorials about Computer Science Concepts, GUI Applications, Machine Learning and Artificial Intelligence, Automation and Web Scraping, Data Science and even Math! 🤓\nI'm here to help you with your programming journey (in particular - your Python programming journey 😉) and show you how many beautiful and powerful things we can do with code! 💪💪💪\n"},
#     'country': 'CA'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUKQdc0-Targ4nDIAUrlfKiA'}},
#    'statistics': {'viewCount': '1936899',
#     'subscriberCount': '65000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '64'}},
#   {'kind': 'youtube#channel',
#    'etag': 'ErKZ2xDTlyyegllqCwbewi6AB5k',
#    'id': 'UCiT9RITQ9PW6BhXK0y2jaeg',
#    'snippet': {'title': 'Ken Jee',
#     'description': 'Data Science and Sports Analytics are my passions. My name is Ken Jee and I have been working in the data science field doing sports analytics for the last 5 years. I have held data science positions in companies ranging from startups to fortune 100 organizations.  I transitioned into data science from a business and consulting background. When I was first starting out on my data science journey I was extremely lost; there were very few resources for me to learn about this field from. I decided to start making YouTube videos to share my experiences and to hopefully help others get break into the data science and sports analytics fields. \n\nOn this channel I produce fun and informative Data Science and Sports Analytics Content. My goal is to provide insight into the data science community, career advice, and sports related analysis.\n\n',
#     'customUrl': 'kenjee1',
#     'publishedAt': '2014-02-28T14:58:24Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AKedOLT9A1OkyZScLlueluVY46CROSJ9pTfn7UgvVHDWyA=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AKedOLT9A1OkyZScLlueluVY46CROSJ9pTfn7UgvVHDWyA=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AKedOLT9A1OkyZScLlueluVY46CROSJ9pTfn7UgvVHDWyA=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'Ken Jee',
#      'description': 'Data Science and Sports Analytics are my passions. My name is Ken Jee and I have been working in the data science field doing sports analytics for the last 5 years. I have held data science positions in companies ranging from startups to fortune 100 organizations.  I transitioned into data science from a business and consulting background. When I was first starting out on my data science journey I was extremely lost; there were very few resources for me to learn about this field from. I decided to start making YouTube videos to share my experiences and to hopefully help others get break into the data science and sports analytics fields. \n\nOn this channel I produce fun and informative Data Science and Sports Analytics Content. My goal is to provide insight into the data science community, career advice, and sports related analysis.\n\n'},
#     'country': 'US'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUiT9RITQ9PW6BhXK0y2jaeg'}},
#    'statistics': {'viewCount': '5290156',
#     'subscriberCount': '175000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '217'}},
#   {'kind': 'youtube#channel',
#    'etag': 'PolKNb6rgbzlSa9gABF3rRrHUFk',
#    'id': 'UC2UXDak6o7rBm23k3Vv5dww',
#    'snippet': {'title': 'Tina Huang',
#     'description': "Hi! My name is Tina and I'm a data scientist at a FAANG company. \n\nThis channel is about data science, learning, and productivity. I love learning new things and my goal is to always minimize effort and maximize outcome! \n\nI strive to do things the most efficient way possible and with the highest reward. I basically refuse to do extra work to achieve my goals c: \n\n----------------------------------------------------------------------------------------------------------------------------------------------------\nA little about myself:\n\nI did my undergraduate at the University of Toronto where I studied pharmacology. I was pre-med but decided I would be a terrible doctor 😱. I worked in bioinformatics for a year and then did my masters in computer science (MCIT) at the University of Pennsylvania. \n\nI interned at Goldman Sachs, then got my current data science job in tech. \n\nTalk soon! \nTina",
#     'customUrl': 'tinahuang1',
#     'publishedAt': '2013-08-28T18:05:17Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/QMaMXCtmRUXUuIWb6sUMLi_ulWNCxPuVnu3I-3IkT1YCJs6XzcxKoOFrzx_WjVW65S46S_pTRQ=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/QMaMXCtmRUXUuIWb6sUMLi_ulWNCxPuVnu3I-3IkT1YCJs6XzcxKoOFrzx_WjVW65S46S_pTRQ=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/QMaMXCtmRUXUuIWb6sUMLi_ulWNCxPuVnu3I-3IkT1YCJs6XzcxKoOFrzx_WjVW65S46S_pTRQ=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'Tina Huang',
#      'description': "Hi! My name is Tina and I'm a data scientist at a FAANG company. \n\nThis channel is about data science, learning, and productivity. I love learning new things and my goal is to always minimize effort and maximize outcome! \n\nI strive to do things the most efficient way possible and with the highest reward. I basically refuse to do extra work to achieve my goals c: \n\n----------------------------------------------------------------------------------------------------------------------------------------------------\nA little about myself:\n\nI did my undergraduate at the University of Toronto where I studied pharmacology. I was pre-med but decided I would be a terrible doctor 😱. I worked in bioinformatics for a year and then did my masters in computer science (MCIT) at the University of Pennsylvania. \n\nI interned at Goldman Sachs, then got my current data science job in tech. \n\nTalk soon! \nTina"},
#     'country': 'US'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UU2UXDak6o7rBm23k3Vv5dww'}},
#    'statistics': {'viewCount': '7407532',
#     'subscriberCount': '220000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '78'}},
#   {'kind': 'youtube#channel',
#    'etag': 'wBJcTiLyJlmt0135fH-Trw2LVtQ',
#    'id': 'UCLLw7jmFsvfIVaUFsLs8mlQ',
#    'snippet': {'title': 'Luke Barousse',
#     'description': "What's up, Data Nerds!  I'm Luke, a data analyst, and I make videos about tech and skills for data science.\n\n\n",
#     'customUrl': 'lukebarousse',
#     'publishedAt': '2020-08-03T09:02:41.213077Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRLX0A7eUKtaU4eoU-y2klRXtbOldExKS6zJ2P-=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRLX0A7eUKtaU4eoU-y2klRXtbOldExKS6zJ2P-=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/AKedOLRLX0A7eUKtaU4eoU-y2klRXtbOldExKS6zJ2P-=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'Luke Barousse',
#      'description': "What's up, Data Nerds!  I'm Luke, a data analyst, and I make videos about tech and skills for data science.\n\n\n"},
#     'country': 'US'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UULLw7jmFsvfIVaUFsLs8mlQ'}},
#    'statistics': {'viewCount': '5202716',
#     'subscriberCount': '109000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '65'}}]}

# %%
### Function to get channel details
def all_channel_details(youtube, channel_ids):
    all_data=[]
    request=youtube.channels().list(
             part='snippet,contentDetails,statistics',
             id=','.join(channel_ids))
    response=request.execute()
    
    for i in range(len(response['items'])):
        data=dict(Channel_name=response['items'][i]['snippet']['title'],
                 Subscribers=response['items'][i]['statistics']['subscriberCount'],
                 Views=response['items'][i]['statistics']['viewCount'],
                 Total_videos=response['items'][i]['statistics']['videoCount'])
        all_data.append(data)
        
    return all_data

# %%
all_channel_details(youtube, channel_ids)
# Out:
# [{'Channel_name': 'Alex The Analyst',
#   'Subscribers': '144000',
#   'Views': '5373565',
#   'Total_videos': '121'},
#  {'Channel_name': 'Ken Jee',
#   'Subscribers': '175000',
#   'Views': '5290156',
#   'Total_videos': '217'},
#  {'Channel_name': 'Tina Huang',
#   'Subscribers': '220000',
#   'Views': '7407532',
#   'Total_videos': '78'},
#  {'Channel_name': 'Luke Barousse',
#   'Subscribers': '109000',
#   'Views': '5202716',
#   'Total_videos': '65'},
#  {'Channel_name': 'Python Simplified',
#   'Subscribers': '65000',
#   'Views': '1936899',
#   'Total_videos': '64'}]

# %%
# create a data frame from the output
df_channel_details=all_channel_details(youtube, channel_ids)
channel_data=pd.DataFrame(df_channel_details)
channel_data.head()
# Out:
#         Channel_name Subscribers    Views Total_videos
# 0         Tina Huang      220000  7407532           78
# 1      Luke Barousse      109000  5202716           65
# 2   Alex The Analyst      144000  5373565          121
# 3            Ken Jee      175000  5290156          217
# 4  Python Simplified       65100  1936899           64

# %%
#check the typs of the data
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers     object
# Views           object
# Total_videos    object
# dtype: object

# %%
# will convert it to the integer for visualization
channel_data['Subscribers']=pd.to_numeric(channel_data['Subscribers'])
channel_data['Views']=pd.to_numeric(channel_data['Views'])
channel_data['Total_videos']=pd.to_numeric(channel_data['Total_videos'])
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# dtype: object

# %%
# let's see who has the highest number of subscriber
sns.set(rc={'figure.figsize':(10,8)})
ax=sns.barplot(x='Channel_name', y='Subscribers', data=channel_data)

# %%
# let's see who has the highest number of views
sns.set(rc={'figure.figsize':(10,8)})
ax=sns.barplot(x='Channel_name', y='Views', data=channel_data)

# %%
# let's see who has the highest number of total videos
sns.set(rc={'figure.figsize':(10,8)})
ax=sns.barplot(x='Channel_name', y='Total_videos', data=channel_data)

# %%
# play_list id
def all_channel_details2(youtube, channel_ids):
    all_data1=[]
    request=youtube.channels().list(
             part='snippet,contentDetails,statistics',
             id=','.join(channel_ids))
    response=request.execute()
    
    for i in range(len(response['items'])):
        data=dict(Channel_name=response['items'][i]['snippet']['title'],
                 Subscribers=response['items'][i]['statistics']['subscriberCount'],
                 Views=response['items'][i]['statistics']['viewCount'],
                 Total_videos=response['items'][i]['statistics']['videoCount'],
                 playlist_id=response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data1.append(data)
        
    return all_data1

# %%
df2=all_channel_details2(youtube, channel_ids)

# %%
channel_data2=pd.DataFrame(df2)
channel_data2.head()
# Out:
#         Channel_name Subscribers    Views Total_videos  \
# 0  Python Simplified       65100  1936899           64
# 1   Alex The Analyst      144000  5373565          121
# 2            Ken Jee      175000  5290156          217
# 3      Luke Barousse      109000  5202716           65
# 4         Tina Huang      220000  7407532           78
#
#                 playlist_id
# 0  UUKQdc0-Targ4nDIAUrlfKiA
# 1  UU7cs8q-gJRlGwj4A8OmCmXg
# 2  UUiT9RITQ9PW6BhXK0y2jaeg
# 3  UULLw7jmFsvfIVaUFsLs8mlQ
# 4  UU2UXDak6o7rBm23k3Vv5dww

# %% [markdown]
# ### Function to get video ids

# %%
channel_data2
# Out:
#         Channel_name Subscribers    Views Total_videos  \
# 0  Python Simplified       65100  1936899           64
# 1   Alex The Analyst      144000  5373565          121
# 2            Ken Jee      175000  5290156          217
# 3      Luke Barousse      109000  5202716           65
# 4         Tina Huang      220000  7407532           78
#
#                 playlist_id
# 0  UUKQdc0-Targ4nDIAUrlfKiA
# 1  UU7cs8q-gJRlGwj4A8OmCmXg
# 2  UUiT9RITQ9PW6BhXK0y2jaeg
# 3  UULLw7jmFsvfIVaUFsLs8mlQ
# 4  UU2UXDak6o7rBm23k3Vv5dww

# %%
playlist_id=channel_data2.loc[channel_data2['Channel_name']=='Alex The Analyst', 'playlist_id'].iloc[0]

# %%
playlist_id
# Out:
# 'UU7cs8q-gJRlGwj4A8OmCmXg'

# %%
def get_video_id(youtube, playlist_id):
    
    request=youtube.playlistItems().list(
              part='contentDetails',
              playlistId=playlist_id,
              maxResults=50)
    response=request.execute()
    
    video_ids=[]
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
    nextpagetoken=response.get('nextPageToken')
    more_pages=True
    while more_pages:
        
        if nextpagetoken is None:
            more_pages=False
        else:
            request=youtube.playlistItems().list(
                       part='contentDetails',
                       playlistId=playlist_id,
                      maxResults=50,
                      pageToken=nextpagetoken)
            response=request.execute()
            for i in range(len(response['items'])):
                    video_ids.append(response['items'][i]['contentDetails']['videoId'])
            nextpagetoken=response.get('nextPageToken')

        
    return video_ids

# %%
video_ids=get_video_id(youtube, playlist_id)

# %% [markdown]
# ### Function to get video details

# %%
video_ids
# Out:
# ['lH7HfwUFnYA',
#  'zOR0-nygfDE',
#  'A4SVUF-fTwc',
#  'FnTunxd8tAM',
#  '-_z_aphWSEo',
#  'pL0jEjeM5hI',
#  'eg_5EAUXs5o',
#  'ebjDwX8sUMk',
#  'f6qxxtWkaUg',
#  '6xv1KvCMF1Q',
#  '465x3JmMJYU',
#  'Ns1ZpTxQnUE',
#  'HiOtQMcI5wg',
#  'CUa30M_FPhk',
#  'DKrSgSy6F1o',
#  '_zxPx1PQCqI',
#  'UGF49YZZRNc',
#  'aLp-6C-p-T0',
#  'ocdwh0KYeUs',
#  'iPYVYBtUTyE',
#  'dMHWOhgzUhU',
#  'A-LkxegXFX8',
#  'RJw-GSXXguA',
#  '8rO7ztF4NtU',
#  'QILNlRvJlfQ',
#  'SVv0WwPzaUg',
#  'qfyynHBFOsM',
#  'm1KcNV-Zhmc',
#  'IZRe0nwkuXc',
#  '9RRQtNnq3s0',
#  'qewHAdfzLOw',
#  'bHssBHfHWmU',
#  'A4OVjWeVb10',
#  'SIseim20_Dc',
#  'NrBJmtD0kEw',
#  'wnapnTAMj68',
#  'duMcYRtQITA',
#  'QG1fo7LFesA',
#  'pYRG5X7110M',
#  'NViKsiGP4TY',
#  '1gdKC5O0Pwc',
#  'GQj6_6V_jVA',
#  'RF0LE3hYFrI',
#  '8o-O6pR6yAE',
#  'eFDbE5Yunj0',
#  'D9bNctNnAig',
#  'VsztBAEtC7c',
#  'T3KMZoXrVTQ',
#  'tJaDicmRW7s',
#  'hfRcaRw_atI',
#  'aPDOGxrONy0',
#  'w25ZjL0OqT4',
#  'EWPeAXrF3zg',
#  'ru0Xdvxd37Q',
#  'BAVPAYWAoC4',
#  'whgwEwA5SHU',
#  'K1WeoKxLZ5o',
#  '0HRgbb1PcDQ',
#  'D6XNlTfglW4',
#  'MQ5UUNjWgug',
#  'JikLVP9DkPs',
#  'yzqpYs7dIqY',
#  '7uH7_DThtX0',
#  'GGLF2jLo8J4',
#  'BGBXnNvWdQ4',
#  'PurMLMKNX0I',
#  'pvxNYyJuiqA',
#  'rZpfNh28nFI',
#  'brxnKIy6Cek',
#  'ySq0cgkZiX4',
#  'aJ9Q10v8Nrc',
#  'C2ik_qR5GOU',
#  'mLUzFXPPa4I',
#  'XmFhpoS6Etk',
#  '1xT68oeQTd0',
#  'eTsHJoMmhYQ',
#  '8SolrjsGqzE',
#  'SKsjWzzz4mY',
#  'Z2AachB309o',
#  '_gP-DH0iZLw',
#  '-Inc1be4zSg',
#  'CsMh7Ykmnw4',
#  'ho2vzKPAD50',
#  '5MZo2RoS8Yo',
#  'M2ySRYpo9S0',
#  'ncXgqGePvwI',
#  'ywZXpfdqg1o',
#  'IqQCBytyATo',
#  'MpIi4HtCiVk',
#  'G4syHs3M82E',
#  'appOFpF2pFg',
#  'B2SPC3Wz1R8',
#  'fUpChfNN5Uo',
#  'Dk7he_yEs4U',
#  'LJtFgnHGAos',
#  'ziurEoqEcO4',
#  'rLKC--8UYSw',
#  'sua7xKN0cPc',
#  'fweZQqB0nwQ',
#  'oXAwKZWfbW0',
#  'bhnrIforc7s',
#  'tYBOMw7Ob8E',
#  'Twusw__OzA8',
#  'lYKkro6rKm0',
#  '9URM1_2S0ho',
#  'qzZU6LAtIig',
#  'LXwfzIRD-Ds',
#  'A9TOuDZTPDU',
#  'PyYgERKq25I',
#  'RSlqWnP-Dy8',
#  '9o9loJpG-t4',
#  'Lacbh0VoT3g',
#  'oZKs2xMbXQE',
#  'N8f7NtDpbxA',
#  'wcKzdRVsMOw',
#  'Ns-8Jsa3mEM',
#  '4rfr6A3lO-Y',
#  'OTq2NRy_AGs',
#  'ya28cb3zFGE',
#  'Hsi2BG0SOiQ',
#  '6lQzbk6_OTw']

# %%
def video_details(youtube, video_ids):
    
    request=youtube.videos().list(
               part='snippet,statistics',
               id=','.join(video_ids[:50]))
    response=request.execute()
    
    return response

# %%
video_details(youtube, video_ids)
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': '_WWfD4O53AES9upUVHF1ljAMS74',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'PrC3exbKrz0HaOoYnIqgxEaOgaM',
#    'id': 'lH7HfwUFnYA',
#    'snippet': {'publishedAt': '2021-12-14T11:30:07Z',
#     'channelId': 'UC7cs8q-gJRlGwj4A8OmCmXg',
#     'title': 'Pivot Tables in Excel | Excel Tutorials for Beginners',
#     'description': "Excel is one of the most used skills in the data world. In this series we will be walking through all of the most important topics that Data Analysts need to know in order to be proficient in Excel.\n\nBike Dataset: https://www.kaggle.com/sadiqshah/bike-store-sales-in-europe/data\n\nUdemy Excel Courses:\nPivot Tables in Excel: https://bit.ly/3GEeYoc\nVisualizations and Charts in Excel: https://bit.ly/3DPwRhK\nAll Excel Essentials: https://bit.ly/31Y2I2Q\n\n____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON/MERCH\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nAlex The Analyst Shop - https://teespring.com/stores/alex-the-analyst-shop\n\n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\nInstagram: @Alex_The_Analyst\n____________________________________________\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lH7HfwUFnYA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lH7HfwUFnYA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lH7HfwUFnYA/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/lH7HfwUFnYA/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/lH7HfwUFnYA/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Alex The Analyst',
#     'tags': ['Data Analyst',
#      'Data Analyst job',
#      'Data Analyst Career',
#      'Data Analytics',
#      'Alex The Analyst',
#      'excel tutorials',
#      'excel for data analysis',
#      'excel for data analysts',
#      'how to use excel',
#      'excel for data science',
#      'excel tutorials for beginners',
#      'pivot tables in excel',
#      'excel for beginners',
#      'how to use a pivot table',
#      'how to use a pivot table in excel',
#      'pivot table excel'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Pivot Tables in Excel | Excel Tutorials for Beginners',
#      'description': "Excel is one of the most used skills in the data world. In this series we will be walking through all of the most important topics that Data Analysts need to know in order to be proficient in Excel.\n\nBike Dataset: https://www.kaggle.com/sadiqshah/bike-store-sales-in-europe/data\n\nUdemy Excel Courses:\nPivot Tables in Excel: https://bit.ly/3GEeYoc\nVisualizations and Charts in Excel: https://bit.ly/3DPwRhK\nAll Excel Essentials: https://bit.ly/31Y2I2Q\n\n____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON/MERCH\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nAlex The Analyst Shop - https://teespring.com/stores/alex-the-analyst-shop\n\n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\nInstagram: @Alex_The_Analyst\n____________________________________________\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*"},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '7557',
#     'likeCount': '388',
#     'favoriteCount': '0',
#     'commentCount': '45'}},
#   {'kind': 'youtube#video',
#    'etag': 'KvEijYov4JdCu6pQGpxYXm_-VTA',
#    'id': 'zOR0-nygfDE',
#    'snippet': {'publishedAt': '2021-12-07T11:30:11Z',
#     'channelId': 'UC7cs8q-gJRlGwj4A8OmCmXg',
#     'title': 'Tableau Tutorial for Beginners | Full Project | Part 5/5',
#     'description': "This is our 5th of 5 tutorials on Tableau. In this series we will learn the UI of tableau as well as how to effectively create visualizations and dashboards. This project is meant for beginners to get their feet wet and go from there onto bigger and better projects.\n\nExcel File: \nhttps://www.kaggle.com/alexanderfreberg/airbnb-listings-2016-dataset\n*File was too large for GitHub so I put it in Kaggle as a workbook*\n\nTo Get Up To Date Data: \nhttp://insideairbnb.com/get-the-data.html\n\nFinal Tableau Dashboard: \nhttps://public.tableau.com/app/profile/alexander.freberg/viz/AirBnBFullProject/Dashboard1\n\n____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nGoogle Data Analyst Certification: http://bit.ly/3cnv9J1\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3xS80YM\nTableau Data Visualization - https://bit.ly/3rpoHII\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON/MERCH\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nAlex The Analyst Shop - https://teespring.com/stores/alex-the-analyst-shop\n\n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\nInstagram: @Alex_The_Analyst\n____________________________________________\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zOR0-nygfDE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zOR0-nygfDE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zOR0-nygfDE/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/zOR0-nygfDE/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/zOR0-nygfDE/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Alex The Analyst',
#     'tags': ['Data Analyst',
#      'Data Analyst job',
#      'Data Analyst Career',
#      'Data Analytics',
#      'Alex The Analyst',
#      'tableau tutorial',
#      'tableau tutorials',
#      'tableau tutorial for beginners',
#      'tableau tutorials for beginner',
#      'tableau tutorials for data analysts',
#      'tableau tutorials for data scientists',
#      'tableau basic',
#      'tableau basics',
#      'tableau projects',
#      'Tableau joins',
#      'joins in tableau',
#      'Tableau project',
#      'tableau portfolio project',
#      'projects in tableau',
#      'project for tableau'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Tableau Tutorial for Beginners | Full Project | Part 5/5',
#      'description': "This is our 5th of 5 tutorials on Tableau. In this series we will learn the UI of tableau as well as how to effectively create visualizations and dashboards. This project is meant for beginners to get their feet wet and go from there onto bigger and better projects.\n\nExcel File: \nhttps://www.kaggle.com/alexanderfreberg/airbnb-listings-2016-dataset\n*File was too large for GitHub so I put it in Kaggle as a workbook*\n\nTo Get Up To Date Data: \nhttp://insideairbnb.com/get-the-data.html\n\nFinal Tableau Dashboard: \nhttps://public.tableau.com/app/profile/alexander.freberg/viz/AirBnBFullProject/Dashboard1\n\n____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nGoogle Data Analyst Certification: http://bit.ly/3cnv9J1\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3xS80YM\nTableau Data Visualization - https://bit.ly/3rpoHII\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON/MERCH\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nAlex The Analyst Shop - https://teespring.com/stores/alex-the-analyst-shop\n\n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\nInstagram: @Alex_The_Analyst\n____________________________________________\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*"},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '6628',
#     'likeCount': '156',
#     'favoriteCount': '0',
#     'commentCount': '26'}},
#   {'kind': 'youtube#video',
#    'etag': '75XRgXBH9YYzQLR01qVhNVGea7E',
#    'id': 'A4SVUF-fTwc',
#    'snippet': {'publishedAt': '2021-11-23T11:30:02Z',
#     'channelId': 'UC7cs8q-gJRlGwj4A8OmCmXg',
#     'title': 'Tableau Tutorial for Beginners | Joins | Part 4/5',
#     'description': "This is our fourth of 5 tutorials on Tableau. In this series we will learn the UI of tableau as well as how to effectively create visualizations and dashboards. \n\nExcel File: https://github.com/AlexTheAnalyst/PortfolioProjects/blob/main/Tableau%20Joins%20File.xlsx\n\nUdemy Black Friday Sale: https://bit.ly/30SfHlR\n\nFavorite Tableau Course:\nTableau A-Z - http://bit.ly/385lYvN\n\nJoins video in SQL: https://www.youtube.com/watch?v=9URM1_2S0ho\n\n____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nGoogle Data Analyst Certification: http://bit.ly/3cnv9J1\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3xS80YM\nTableau Data Visualization - https://bit.ly/3rpoHII\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON/MERCH\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nAlex The Analyst Shop - https://teespring.com/stores/alex-the-analyst-shop\n\n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\nInstagram: @Alex_The_Analyst\n____________________________________________\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/A4SVUF-fTwc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/A4SVUF-fTwc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/A4SVUF-fTwc/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/A4SVUF-fTwc/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/A4SVUF-fTwc/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Alex The Analyst',
#     'tags': ['Data Analyst',
#      'Data Analyst job',
#      'Data Analyst Career',
#      'Data Analytics',
#      'Alex The Analyst',
#      'tableau tutorial',
#      'tableau tutorials',
#      'tableau tutorial for beginners',
#      'tableau tutorials for beginner',
#      'tableau tutorials for data analysts',
#      'tableau tutorials for data scientists',
#      'tableau basic',
#      'tableau basics',
#      'tableau projects',
#      'Tableau joins',
#      'joins in tableau'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Tableau Tutorial for Beginners | Joins | Part 4/5',
#      'description': "This is our fourth of 5 tutorials on Tableau. In this series we will learn the UI of tableau as well as how to effectively create visualizations and dashboards. \n\nExcel File: https://github.com/AlexTheAnalyst/PortfolioProjects/blob/main/Tableau%20Joins%20File.xlsx\n\nUdemy Black Friday Sale: https://bit.ly/30SfHlR\n\nFavorite Tableau Course:\nTableau A-Z - http://bit.ly/385lYvN\n\nJoins video in SQL: https://www.youtube.com/watch?v=9URM1_2S0ho\n\n____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nGoogle Data Analyst Certification: http://bit.ly/3cnv9J1\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3xS80YM\nTableau Data Visualization - https://bit.ly/3rpoHII\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON/MERCH\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nAlex The Analyst Shop - https://teespring.com/stores/alex-the-analyst-shop\n\n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\nInstagram: @Alex_The_Analyst\n____________________________________________\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*"},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '5435',
#     'likeCount': '160',
#     'favoriteCount': '0',
#     'commentCount': '14'}},
#   {'kind': 'youtube#video',
#    'etag': 'w_2EAlIPdTvk8ketFnCdbq4LnQo',
#    'id': 'FnTunxd8tAM',
#    'snippet': {'publishedAt': '2021-11-18T11:30:08Z',
#     'channelId': 'UC7cs8q-gJRlGwj4A8OmCmXg',
#     'title': 'Top 5 Major Red Flags in Job Descriptions',
#     'description': "Don't accept every job offer you get! Make sure it's the right fit for you. Here are some red flags that you should be looking out for when applying to Data Analyst jobs.\n\n____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nGoogle Data Analyst Certification: http://bit.ly/3cnv9J1\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3xS80YM\nTableau Data Visualization - https://bit.ly/3rpoHII\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON/MERCH\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nAlex The Analyst Shop - https://teespring.com/stores/alex-the-analyst-shop\n\n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\nInstagram: @Alex_The_Analyst\n____________________________________________\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FnTunxd8tAM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/FnTunxd8tAM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/FnTunxd8tAM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/FnTunxd8tAM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/FnTunxd8tAM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Alex The Analyst',
#     'tags': ['Data Analyst',
#      'Data Analyst job',
#      'Data Analyst Career',
#      'Data Analytics',
#      'Alex The Analyst',
#      'red flags',
#      'red flags in jobs',
#      'major red flags',
#      'red flags in data analyst jobs',
#      'red flags in data science jobs',
#      'big red flags',
#      'red flags in job interviews'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Top 5 Major Red Flags in Job Descriptions',
#      'description': "Don't accept every job offer you get! Make sure it's the right fit for you. Here are some red flags that you should be looking out for when applying to Data Analyst jobs.\n\n____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nGoogle Data Analyst Certification: http://bit.ly/3cnv9J1\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3xS80YM\nTableau Data Visualization - https://bit.ly/3rpoHII\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON/MERCH\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nAlex The Analyst Shop - https://teespring.com/stores/alex-the-analyst-shop\n\n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\nInstagram: @Alex_The_Analyst\n____________________________________________\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*"},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '9254',
#     'likeCount': '561',
#     'favoriteCount': '0',
#     'commentCount': '58'}},
#   {'kind': 'youtube#video',
#    'etag': '99PT3z0b3_-7KC-h9fWcJnWEAzk',
#    'id': '-_z_aphWSEo',
#    'snippet': {'publishedAt': '2021-11-08T11:30:01Z',
#     'channelId': 'UC7cs8q-gJRlGwj4A8OmCmXg',
#     'title': 'Truth About My Job (Song) - As a Data Analyst',
#     'description': "This song is for all the people who need to know the truth about working in tech job.\n\n____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nGoogle Data Analyst Certification: http://bit.ly/3cnv9J1\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3xS80YM\nTableau Data Visualization - https://bit.ly/3rpoHII\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON/MERCH\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nAlex The Analyst Shop - https://teespring.com/stores/alex-the-analyst-shop\n\n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\n____________________________________________\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-_z_aphWSEo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/-_z_aphWSEo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/-_z_aphWSEo/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/-_z_aphWSEo/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/-_z_aphWSEo/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Alex The Analyst',
#     'tags': ['Data Analyst',
#      'Data Analyst job',
#      'Data Analyst Career',
#      'Data Analytics',
#      'Alex The Analyst',
#      'truth about my job song',
#      'truth song',
#      'truth about data analytics',
#      'reality of data analytics',
#      'reality of data science',
#      'data science song',
#      'data science songs',
#      'song about data',
#      'data song',
#      'songs about data science',
#      'truth about data analyst job',
#      'truth about data science song'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Truth About My Job (Song) - As a Data Analyst',
#      'description': "This song is for all the people who need to know the truth about working in tech job.\n\n____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nGoogle Data Analyst Certification: http://bit.ly/3cnv9J1\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3xS80YM\nTableau Data Visualization - https://bit.ly/3rpoHII\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON/MERCH\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nAlex The Analyst Shop - https://teespring.com/stores/alex-the-analyst-shop\n\n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\n____________________________________________\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*"},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '6940',
#     'likeCount': '657',
#     'favoriteCount': '0',
#     'commentCount': '90'}},
#   {'kind': 'youtube#video',
#    'etag': 'USXGokuKesy0Ci2hM90Z4EXcOsA',
#    'id': 'pL0jEjeM5hI',
#    'snippet': {'publishedAt': '2021-10-26T10:00:23Z',
#     'channelId': 'UC7cs8q-gJRlGwj4A8OmCmXg',
#     'title': 'How to Grow Your Analytics Career | Alteryx Webinar Oct 2021 | Tips to Break Into Analytics',
#     'description': "Last week I partnered with Alteryx to host a webinar about Data Analytics. Here are some of the highlights from that webinar.\n\nLink to Alteryx Website: https://www.alteryx.com/\nAlteryx Free Trial: https://www.alteryx.com/designer-trial/free-trial-alteryx\n\nLink to full video: https://pages.alteryx.com/surviving-to-thriving-leveraging-automation-to-accelerate-analytics-on-demand.html\n\n0:00 Introduction\n1:01 How We Got Started In Analytics\n8:19 Biggest Factor for Success as an Analyst\n10:53 How Have You Learned New Skills\n13:25 Advice for Some Just Starting Out in Analytics\n16:29 What Does the Job Market Look Like Today\n17:36 Certifications or Formal Education?\n18:30 Can Non-Computer Science Grads Find Jobs?\n19:36 Am I Too Old at 43 Years Old?\n____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nGoogle Data Analyst Certification: http://bit.ly/3cnv9J1\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3xS80YM\nTableau Data Visualization - https://bit.ly/3rpoHII\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON/MERCH\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nAlex The Analyst Shop - https://teespring.com/stores/alex-the-analyst-shop\n\n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\n____________________________________________\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*\n\n\nThanks for Watching!",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pL0jEjeM5hI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pL0jEjeM5hI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pL0jEjeM5hI/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/pL0jEjeM5hI/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/pL0jEjeM5hI/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Alex The Analyst',
#     'tags': ['Data Analyst',
#      'Data Analyst job',
#      'Data Analyst Career',
#      'Data Analytics',
#      'Alex The Analyst',
#      'alteryx',
#      'webinar',
#      'alteryx webinar',
#      'how to become a data analyst',
#      'breaking into the data analyst field',
#      'data analytics',
#      'alteryx data analyst'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'How to Grow Your Analytics Career | Alteryx Webinar Oct 2021 | Tips to Break Into Analytics',
#      'description': "Last week I partnered with Alteryx to host a webinar about Data Analytics. Here are some of the highlights from that webinar.\n\nLink to Alteryx Website: https://www.alteryx.com/\nAlteryx Free Trial: https://www.alteryx.com/designer-trial/free-trial-alteryx\n\nLink to full video: https://pages.alteryx.com/surviving-to-thriving-leveraging-automation-to-accelerate-analytics-on-demand.html\n\n0:00 Introduction\n1:01 How We Got Started In Analytics\n8:19 Biggest Factor for Success as an Analyst\n10:53 How Have You Learned New Skills\n13:25 Advice for Some Just Starting Out in Analytics\n16:29 What Does the Job Market Look Like Today\n17:36 Certifications or Formal Education?\n18:30 Can Non-Computer Science Grads Find Jobs?\n19:36 Am I Too Old at 43 Years Old?\n____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nGoogle Data Analyst Certification: http://bit.ly/3cnv9J1\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3xS80YM\nTableau Data Visualization - https://bit.ly/3rpoHII\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON/MERCH\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nAlex The Analyst Shop - https://teespring.com/stores/alex-the-analyst-shop\n\n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\n____________________________________________\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*\n\n\nThanks for Watching!"},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '9258',
#     'likeCount': '284',
#     'favoriteCount': '0',
#     'commentCount': '35'}},
#   {'kind': 'youtube#video',
#    'etag': 'aOh-7E6C1hMwXbXEG3nd2W-fbpQ',
#    'id': 'eg_5EAUXs5o',
#    'snippet': {'publishedAt': '2021-10-19T10:00:16Z',
#     'channelId': 'UC7cs8q-gJRlGwj4A8OmCmXg',
#     'title': 'Choosing a Domain to Make More Money',
#     'description': "Today we ]discuss why you need to choose a domain when you start getting into your career. \n\n365 Data Science Free Month Link: https://365datascience.pxf.io/a1Abxo\n\nInstagram: Alex_The_Analyst\n\n____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nGoogle Data Analyst Certification: http://bit.ly/3cnv9J1\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3xS80YM\nTableau Data Visualization - https://bit.ly/3rpoHII\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON/MERCH\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nAlex The Analyst Shop - https://teespring.com/stores/alex-the-analyst-shop\n\n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\n____________________________________________\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eg_5EAUXs5o/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/eg_5EAUXs5o/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/eg_5EAUXs5o/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/eg_5EAUXs5o/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/eg_5EAUXs5o/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Alex The Analyst',
#     'tags': ['Data Analyst',
#      'Data Analyst job',
#      'Data Analyst Career',
#      'Data Analytics',
#      'Alex The Analyst',
#      'domain knowledge',
#      'data science domain',
#      'data analyst domain',
#      'is domain knowledge important',
#      'domain knowledge to make more money',
#      'domain vs technical skills',
#      'choosing a domain',
#      'how to choose a domain'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Choosing a Domain to Make More Money',
#      'description': "Today we ]discuss why you need to choose a domain when you start getting into your career. \n\n365 Data Science Free Month Link: https://365datascience.pxf.io/a1Abxo\n\nInstagram: Alex_The_Analyst\n\n____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nGoogle Data Analyst Certification: http://bit.ly/3cnv9J1\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3xS80YM\nTableau Data Visualization - https://bit.ly/3rpoHII\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON/MERCH\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nAlex The Analyst Shop - https://teespring.com/stores/alex-the-analyst-shop\n\n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\n____________________________________________\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*"},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '9214',
#     'likeCount': '515',
#     'favoriteCount': '0',
#     'commentCount': '65'}},
#   {'kind': 'youtube#video',
#    'etag': 'HSgXyoWDtbwqm31GJSRnvKhrs3k',
#    'id': 'ebjDwX8sUMk',
#    'snippet': {'publishedAt': '2021-10-05T11:30:14Z',
#     'channelId': 'UC7cs8q-gJRlGwj4A8OmCmXg',
#     'title': 'Tableau Tutorial for Beginners | Density Maps | Bar and Line Graphs | More Visualizations | Part 3/5',
#     'description': "This is our third of 5 tutorials on Tableau. In this series we will learn the UI of tableau as well as how to effectively create visualizations and dashboards. \n\nAlteryx Sign Up Link: https://bit.ly/2Y7ZzeM\n\nDataset: \nhttps://www.kaggle.com/gregorut/videogamesales\nhttps://www.kaggle.com/starbucks/store-locations\n\nFavorite Tableau Courses:\nTableau Data Visualization - https://bit.ly/3rpoHII\nTableau A-Z - http://bit.ly/385lYvN\n\n____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nGoogle Data Analyst Certification: http://bit.ly/3cnv9J1\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3xS80YM\nTableau Data Visualization - https://bit.ly/3rpoHII\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON/MERCH\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nAlex The Analyst Shop - https://teespring.com/stores/alex-the-analyst-shop\n\n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\n____________________________________________\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ebjDwX8sUMk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ebjDwX8sUMk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ebjDwX8sUMk/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/ebjDwX8sUMk/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/ebjDwX8sUMk/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Alex The Analyst',
#     'tags': ['Data Analyst',
#      'Data Analyst job',
#      'Data Analyst Career',
#      'Data Analytics',
#      'Alex The Analyst',
#      'tableau tutorial',
#      'tableau tutorials',
#      'tableau tutorial for beginners',
#      'tableau tutorials for beginner',
#      'tableau tutorials for data analysts',
#      'tableau tutorials for data scientists',
#      'tableau basic',
#      'tableau basics',
#      'tableau projects'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Tableau Tutorial for Beginners | Density Maps | Bar and Line Graphs | More Visualizations | Part 3/5',
#      'description': "This is our third of 5 tutorials on Tableau. In this series we will learn the UI of tableau as well as how to effectively create visualizations and dashboards. \n\nAlteryx Sign Up Link: https://bit.ly/2Y7ZzeM\n\nDataset: \nhttps://www.kaggle.com/gregorut/videogamesales\nhttps://www.kaggle.com/starbucks/store-locations\n\nFavorite Tableau Courses:\nTableau Data Visualization - https://bit.ly/3rpoHII\nTableau A-Z - http://bit.ly/385lYvN\n\n____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nGoogle Data Analyst Certification: http://bit.ly/3cnv9J1\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3xS80YM\nTableau Data Visualization - https://bit.ly/3rpoHII\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON/MERCH\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nAlex The Analyst Shop - https://teespring.com/stores/alex-the-analyst-shop\n\n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\n____________________________________________\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*"},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '8418',
#     'likeCount': '283',
#     'favoriteCount': '0',
#     'commentCount': '40'}},
#   {'kind': 'youtube#video',
#    'etag': '9fg0CvAiJi76TrRGPx5u9H1qLbQ',
#    'id': 'f6qxxtWkaUg',
#    'snippet': {'publishedAt': '2021-09-28T11:30:07Z',
#     'channelId': 'UC7cs8q-gJRlGwj4A8OmCmXg',
#     'title': 'Tableau Tutorial for Beginners | Calculated Fields | Bins | Part 2/5',
#     'description': "This is our second of 5 tutorials on Tableau. In this series we will learn the UI of tableau as well as how to effectively create visualizations and dashboards. \n\nDataset: https://www.kaggle.com/gregorut/videogamesales\n\nFavorite Tableau Courses:\nTableau Data Visualization - https://bit.ly/3rpoHII\nTableau A-Z - http://bit.ly/385lYvN\n\n____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nGoogle Data Analyst Certification: http://bit.ly/3cnv9J1\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3xS80YM\nTableau Data Visualization - https://bit.ly/3rpoHII\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON/MERCH\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nAlex The Analyst Shop - https://teespring.com/stores/alex-the-analyst-shop\n\n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\n____________________________________________\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/f6qxxtWkaUg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/f6qxxtWkaUg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/f6qxxtWkaUg/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/f6qxxtWkaUg/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/f6qxxtWkaUg/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Alex The Analyst',
#     'tags': ['Data Analyst',
#      'Data Analyst job',
#      'Data Analyst Career',
#      'Data Analytics',
#      'Alex The Analyst',
#      'tableau tutorial',
#      'tableau tutorials',
#      'tableau tutorial for beginners',
#      'tableau tutorials for beginner',
#      'tableau tutorials for data analysts',
#      'tableau tutorials for data scientists',
#      'tableau basic',
#      'tableau basics',
#      'tableau projects'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Tableau Tutorial for Beginners | Calculated Fields | Bins | Part 2/5',
# ...
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/T3KMZoXrVTQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/T3KMZoXrVTQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/T3KMZoXrVTQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/T3KMZoXrVTQ/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/T3KMZoXrVTQ/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Alex The Analyst',
#     'tags': ['Data Analyst',
#      'Data Analyst job',
#      'Data Analyst Career',
#      'Data Analytics',
#      'Alex The Analyst',
#      'alex the analyst',
#      'best data analyst skills',
#      'top data analyst skills',
#      'data analyst skills',
#      'top 5 data analyst skills',
#      'skill for data analysts',
#      'skills for data analysts',
#      'data analyst skill set',
#      'data analyst skills in 2021',
#      'best data analyst skills in 2021',
#      'data analyst skills required',
#      'data analyst skills needed',
#      'skills needed to become a data analyst',
#      'skills to become data analyst'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Top 5 Data Analyst Skills',
#      'description': "Top Data Analyst Skills in 2021!\n\nIf you want to become a Data Analyst this year you need to know where to focus your time. I highly recommend learning the skills discussed in this video as I think it will give you the best chance to becoming a Data Analyst.\n____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nDatabase and SQL for Data Science - https://bit.ly/2zUk0zL\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3dYJ6w0\nTableau Data Visualization - https://bit.ly/2AHCNPd\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON/MERCH\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nAlex The Analyst Shop - teespring.com/stores/alex-the-analyst-shop\n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\n____________________________________________\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*"},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '15140',
#     'likeCount': '891',
#     'favoriteCount': '0',
#     'commentCount': '163'}},
#   {'kind': 'youtube#video',
#    'etag': '9Q-KRbSXAf8ECqJMJSKsSaisnY4',
#    'id': 'tJaDicmRW7s',
#    'snippet': {'publishedAt': '2021-01-07T12:00:28Z',
#     'channelId': 'UC7cs8q-gJRlGwj4A8OmCmXg',
#     'title': 'Best Industries for Data Analysts in 2021 | Alex The Analyst Show | Episode 17',
#     'description': "Every industry has changed since covid hit in 2020. Let's take a look at the best and worst industries in 2021 to help you make the best decision for your career!\n\nAlex The Analyst Shop - https://teespring.com/stores/alex-the-analyst-shop\n\nLinks:\nhttps://towardsdatascience.com/5-industries-becoming-defined-by-big-data-and-analytics-e3e8cc0c0cf\nhttps://www.geeksforgeeks.org/11-industries-that-benefits-the-most-from-data-science/\nhttps://www.quora.com/What-are-the-top-10-industry-sectors-that-are-using-data-analytics-in-the-world\nhttps://datafloq.com/read/top-industries-for-data-science-professionals/6698\nhttps://www.infragistics.com/community/blogs/b/mobileman/posts/top-10-industries-benefiting-the-most-from-data-analytics\n\n ____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nDatabase and SQL for Data Science - https://bit.ly/2zUk0zL\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3dYJ6w0\nTableau Data Visualization - https://bit.ly/2AHCNPd\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nEvery dollar donated is put back into my channel to make my videos even better. Thank you all so much for your support! \n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\n____________________________________________\n\n0:00 - Introduction\n2:53 - Top tier industries \n6:21 - Mid tier industries \n11:31 - Low tier industries \n18:25 - How you can support me\n19:15 - Question of the week\n21:59 - Shhh, super duper secret club\n24:57 - Final thoughts\n*Shoutout to my man Wilson for this*\n\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tJaDicmRW7s/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/tJaDicmRW7s/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/tJaDicmRW7s/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/tJaDicmRW7s/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/tJaDicmRW7s/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Alex The Analyst',
#     'tags': ['Data Analyst',
#      'Data Analyst job',
#      'Data Analyst Career',
#      'Data Analytics',
#      'Alex The Analyst',
#      'data analyst industries',
#      'data science industries',
#      'best data analyst industries',
#      'best data science industries',
#      'data industries',
#      'best data industries'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Best Industries for Data Analysts in 2021 | Alex The Analyst Show | Episode 17',
#      'description': "Every industry has changed since covid hit in 2020. Let's take a look at the best and worst industries in 2021 to help you make the best decision for your career!\n\nAlex The Analyst Shop - https://teespring.com/stores/alex-the-analyst-shop\n\nLinks:\nhttps://towardsdatascience.com/5-industries-becoming-defined-by-big-data-and-analytics-e3e8cc0c0cf\nhttps://www.geeksforgeeks.org/11-industries-that-benefits-the-most-from-data-science/\nhttps://www.quora.com/What-are-the-top-10-industry-sectors-that-are-using-data-analytics-in-the-world\nhttps://datafloq.com/read/top-industries-for-data-science-professionals/6698\nhttps://www.infragistics.com/community/blogs/b/mobileman/posts/top-10-industries-benefiting-the-most-from-data-analytics\n\n ____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nDatabase and SQL for Data Science - https://bit.ly/2zUk0zL\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3dYJ6w0\nTableau Data Visualization - https://bit.ly/2AHCNPd\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nEvery dollar donated is put back into my channel to make my videos even better. Thank you all so much for your support! \n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\n____________________________________________\n\n0:00 - Introduction\n2:53 - Top tier industries \n6:21 - Mid tier industries \n11:31 - Low tier industries \n18:25 - How you can support me\n19:15 - Question of the week\n21:59 - Shhh, super duper secret club\n24:57 - Final thoughts\n*Shoutout to my man Wilson for this*\n\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*"},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '8602',
#     'likeCount': '320',
#     'favoriteCount': '0',
#     'commentCount': '133'}},
#   {'kind': 'youtube#video',
#    'etag': 'kkeMSloeTjVDEzIFkrZ6XZFFr0o',
#    'id': 'hfRcaRw_atI',
#    'snippet': {'publishedAt': '2021-01-05T12:00:10Z',
#     'channelId': 'UC7cs8q-gJRlGwj4A8OmCmXg',
#     'title': 'Top 5 Data Analyst Interview Mistakes',
#     'description': "Stop making these Data Analyst Interview Mistakes!\n\nI would consider myself a seasoned professional in this regard. I have made so many mistakes in interviews! Hopefully in this interview I can identify some that you may need to work on. Make sure to be fully prepared for that next interview!\n\nAlex The Analyst Shop - teespring.com/stores/alex-the-analyst-shop\n ____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nDatabase and SQL for Data Science - https://bit.ly/2zUk0zL\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3dYJ6w0\nTableau Data Visualization - https://bit.ly/2AHCNPd\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nEvery dollar donated is put back into my channel to make my videos even better. Thank you all so much for your support! \n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\n____________________________________________\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hfRcaRw_atI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hfRcaRw_atI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hfRcaRw_atI/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/hfRcaRw_atI/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/hfRcaRw_atI/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Alex The Analyst',
#     'tags': ['Data Analyst',
#      'Data Analyst job',
#      'Data Analyst Career',
#      'Data Analytics',
#      'Alex The Analyst',
#      'Data Analyst Interview',
#      'Data Analyst Interviews',
#      'Data Analyst Interview Mistakes',
#      'top interview mistakes',
#      'Interview Mistakes',
#      'Data Analyst interview questions',
#      'data analyst interview preparation'],
#     'categoryId': '27',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'Top 5 Data Analyst Interview Mistakes',
#      'description': "Stop making these Data Analyst Interview Mistakes!\n\nI would consider myself a seasoned professional in this regard. I have made so many mistakes in interviews! Hopefully in this interview I can identify some that you may need to work on. Make sure to be fully prepared for that next interview!\n\nAlex The Analyst Shop - teespring.com/stores/alex-the-analyst-shop\n ____________________________________________ \n\nSUBSCRIBE!\nDo you want to become a Data Analyst? That's what this channel is all about! My goal is to help you learn everything you need in order to start your career or even switch your career into Data Analytics. Be sure to subscribe to not miss out on any content!\n____________________________________________ \n\nRESOURCES:\n\nUdemy Courses:\nPython for Data Analysis and Visualization- https://bit.ly/3hhX4LX\nStatistics for Data Science - https://bit.ly/37jqDbq\nSQL for Data Analysts (SSMS) - https://bit.ly/3fkqEij\nTableau A-Z - http://bit.ly/385lYvN\n\nCoursera Courses:\nDatabase and SQL for Data Science - https://bit.ly/2zUk0zL\nData Analysis with Python - https://bit.ly/3geiVDG\nData Analysis Specialization - https://bit.ly/3dYJ6w0\nTableau Data Visualization - https://bit.ly/2AHCNPd\n\n*Please note I may earn a small commission for any purchase through these links - Thanks for supporting the channel!*\n____________________________________________ \n\nSUPPORT MY CHANNEL - PATREON\n\nPatreon Page - https://www.patreon.com/AlexTheAnalyst\n\nEvery dollar donated is put back into my channel to make my videos even better. Thank you all so much for your support! \n____________________________________________ \n\nWebsites: \nGitHub: https://github.com/AlexTheAnalyst\n____________________________________________\n\n*All opinions or statements in this video are my own and do not reflect the opinion of the company I work for or have ever worked for*"},
#     'defaultAudioLanguage': 'en'},
#    'statistics': {'viewCount': '11019',
#     'likeCount': '451',
#     'favoriteCount': '0',
#     'commentCount': '51'}}],
#  'pageInfo': {'totalResults': 50, 'resultsPerPage': 50}}

# %% [markdown]
# ### ANother function

# %%
def get_video_name(youtube, video_ids):
    all_video_info=[]
    
    for i in range(0,len(video_ids),50):
        request=youtube.videos().list(
                  part='snippet,statistics',
                  id=','.join(video_ids[i:i+50]))

        
        response=request.execute()
        
        for video in response['items']:
            video_statistics=dict(Title=video['snippet']['title'],
                                 Published_date=video['snippet']['publishedAt'],
                                 Views=video['statistics']['viewCount'],
                                 Likes=video['statistics']['likeCount'],
                                 Favourites=video['statistics']['favoriteCount'],
                                 Comments=video['statistics']['commentCount']
                                 )
            all_video_info.append(video_statistics)
            
    return all_video_info

# %%
get_video_name(youtube, video_ids)
# Out:
# [{'Title': 'Pivot Tables in Excel | Excel Tutorials for Beginners',
#   'Published_date': '2021-12-14T11:30:07Z',
#   'Views': '7574',
#   'Likes': '389',
#   'Favourites': '0',
#   'Comments': '45'},
#  {'Title': 'Tableau Tutorial for Beginners | Full Project | Part 5/5',
#   'Published_date': '2021-12-07T11:30:11Z',
#   'Views': '6632',
#   'Likes': '156',
#   'Favourites': '0',
#   'Comments': '26'},
#  {'Title': 'Tableau Tutorial for Beginners | Joins | Part 4/5',
#   'Published_date': '2021-11-23T11:30:02Z',
#   'Views': '5436',
#   'Likes': '160',
#   'Favourites': '0',
#   'Comments': '14'},
#  {'Title': 'Top 5 Major Red Flags in Job Descriptions',
#   'Published_date': '2021-11-18T11:30:08Z',
#   'Views': '9255',
#   'Likes': '561',
#   'Favourites': '0',
#   'Comments': '58'},
#  {'Title': 'Truth About My Job (Song) - As a Data Analyst',
#   'Published_date': '2021-11-08T11:30:01Z',
#   'Views': '6940',
#   'Likes': '657',
#   'Favourites': '0',
#   'Comments': '90'},
#  {'Title': 'How to Grow Your Analytics Career | Alteryx Webinar Oct 2021 | Tips to Break Into Analytics',
#   'Published_date': '2021-10-26T10:00:23Z',
#   'Views': '9258',
#   'Likes': '284',
#   'Favourites': '0',
#   'Comments': '35'},
#  {'Title': 'Choosing a Domain to Make More Money',
#   'Published_date': '2021-10-19T10:00:16Z',
#   'Views': '9216',
#   'Likes': '516',
#   'Favourites': '0',
#   'Comments': '65'},
#  {'Title': 'Tableau Tutorial for Beginners | Density Maps | Bar and Line Graphs | More Visualizations | Part 3/5',
#   'Published_date': '2021-10-05T11:30:14Z',
#   'Views': '8421',
#   'Likes': '283',
#   'Favourites': '0',
#   'Comments': '40'},
#  {'Title': 'Tableau Tutorial for Beginners | Calculated Fields | Bins | Part 2/5',
#   'Published_date': '2021-09-28T11:30:07Z',
#   'Views': '7786',
#   'Likes': '295',
#   'Favourites': '0',
#   'Comments': '39'},
#  {'Title': 'Tableau Tutorial for Beginners | Installing Tableau | Building First Visualization | Part 1/5',
#   'Published_date': '2021-09-21T11:30:01Z',
#   'Views': '25414',
#   'Likes': '993',
#   'Favourites': '0',
#   'Comments': '88'},
#  {'Title': 'How NOT to Become a Data Analyst (Funny?)',
#   'Published_date': '2021-09-07T11:30:01Z',
#   'Views': '13598',
#   'Likes': '621',
#   'Favourites': '0',
#   'Comments': '108'},
#  {'Title': '100k Subscriber Play Button Unboxing',
#   'Published_date': '2021-08-31T11:30:04Z',
#   'Views': '2389',
#   'Likes': '231',
#   'Favourites': '0',
#   'Comments': '96'},
#  {'Title': 'Amazon Web Scraping Using Python | Data Analyst Portfolio Project',
#   'Published_date': '2021-08-24T11:30:01Z',
#   'Views': '28194',
#   'Likes': '1088',
#   'Favourites': '0',
#   'Comments': '146'},
#  {'Title': 'Interviewing with PwC for a Senior Data Analyst Position',
#   'Published_date': '2021-08-17T11:30:01Z',
#   'Views': '47611',
#   'Likes': '1381',
#   'Favourites': '0',
#   'Comments': '132'},
#  {'Title': '100k Livestream | Announcing Giveaway Winners | Trimming Mustache | Answering Questions',
#   'Published_date': '2021-08-13T14:38:59Z',
#   'Views': '4552',
#   'Likes': '189',
#   'Favourites': '0',
#   'Comments': '26'},
#  {'Title': 'I Am No Longer a Data Analyst | Turning Down PwC | New Job',
#   'Published_date': '2021-08-11T11:30:05Z',
#   'Views': '92168',
#   'Likes': '3324',
#   'Favourites': '0',
#   'Comments': '463'},
#  {'Title': 'When To Start Applying To Your First Data Analyst Job',
#   'Published_date': '2021-07-21T11:30:04Z',
#   'Views': '28442',
#   'Likes': '1896',
#   'Favourites': '0',
#   'Comments': '177'},
#  {'Title': 'Why You Need to Stop Taking Courses (From an Ex-Course Addict)',
#   'Published_date': '2021-07-13T11:30:00Z',
#   'Views': '119225',
#   'Likes': '5161',
#   'Favourites': '0',
#   'Comments': '360'},
#  {'Title': 'How to Create a Portfolio Website for FREE',
#   'Published_date': '2021-06-29T11:30:13Z',
#   'Views': '33746',
#   'Likes': '1428',
#   'Favourites': '0',
#   'Comments': '139'},
#  {'Title': 'Data Analyst Portfolio Project | Correlation in Python | Project 4/4',
#   'Published_date': '2021-06-22T11:30:05Z',
#   'Views': '28751',
#   'Likes': '852',
#   'Favourites': '0',
#   'Comments': '167'},
#  {'Title': 'How To Get a Data Analyst Job (with No Experience)',
#   'Published_date': '2021-06-08T11:30:12Z',
#   'Views': '165198',
#   'Likes': '8378',
#   'Favourites': '0',
#   'Comments': '427'},
#  {'Title': 'My Wife Answers Subscribers Questions About Me | Alex The Analyst Show | Episode 19',
#   'Published_date': '2021-06-03T11:30:01Z',
#   'Views': '4846',
#   'Likes': '203',
#   'Favourites': '0',
#   'Comments': '104'},
#  {'Title': 'Favorite Tableau and Power BI Courses on Udemy',
#   'Published_date': '2021-06-01T11:30:03Z',
#   'Views': '12805',
#   'Likes': '519',
#   'Favourites': '0',
#   'Comments': '74'},
#  {'Title': 'Data Analyst Portfolio Project | Data Cleaning in SQL | Project 3/4',
#   'Published_date': '2021-05-25T11:30:01Z',
#   'Views': '48029',
#   'Likes': '1503',
#   'Favourites': '0',
#   'Comments': '236'},
#  {'Title': 'Data Analyst Portfolio Project | Tableau Visualization | Project 2/4',
#   'Published_date': '2021-05-18T11:30:04Z',
#   'Views': '70204',
#   'Likes': '1601',
#   'Favourites': '0',
#   'Comments': '194'},
#  {'Title': 'Asking My Family What I Do For a Living',
#   'Published_date': '2021-05-11T11:00:08Z',
#   'Views': '3258',
#   'Likes': '182',
#   'Favourites': '0',
#   'Comments': '56'},
#  {'Title': 'Data Analyst Portfolio Project | SQL Data Exploration | Project 1/4',
#   'Published_date': '2021-05-04T11:00:31Z',
#   'Views': '275236',
#   'Likes': '7666',
#   'Favourites': '0',
#   'Comments': '945'},
#  {'Title': 'Advanced SQL Tutorial | Subqueries',
#   'Published_date': '2021-04-20T11:00:32Z',
#   'Views': '36521',
#   'Likes': '1239',
#   'Favourites': '0',
#   'Comments': '69'},
#  {'Title': 'Data Analyst Q/A #6 | Why Am I Not a Data Scientist?',
#   'Published_date': '2021-04-15T11:00:06Z',
#   'Views': '15382',
#   'Likes': '616',
#   'Favourites': '0',
#   'Comments': '143'},
#  {'Title': 'Google vs IBM Data Analytics Certificates | Which is Better?',
#   'Published_date': '2021-04-13T11:00:04Z',
#   'Views': '108778',
#   'Likes': '4590',
#   'Favourites': '0',
#   'Comments': '417'},
#  {'Title': 'Data Analyst Reacts: How to Go From Data Analyst to Data Scientist',
#   'Published_date': '2021-04-06T11:00:12Z',
#   'Views': '16146',
#   'Likes': '628',
#   'Favourites': '0',
#   'Comments': '81'},
#  {'Title': 'Laptops for Data Analysts |  Specifications + Recommendations',
#   'Published_date': '2021-03-30T11:00:18Z',
#   'Views': '50049',
#   'Likes': '1403',
#   'Favourites': '0',
#   'Comments': '183'},
#  {'Title': 'Best Machine Learning Courses on Coursera',
#   'Published_date': '2021-03-23T11:00:02Z',
#   'Views': '13619',
#   'Likes': '593',
#   'Favourites': '0',
#   'Comments': '59'},
#  {'Title': 'Will Data Analysts Be Automated? | Alex The Analyst | Episode 18',
#   'Published_date': '2021-03-18T11:00:08Z',
#   'Views': '11225',
#   'Likes': '378',
#   'Favourites': '0',
#   'Comments': '97'},
#  {'Title': 'Advanced SQL Tutorial | Stored Procedures + Use Cases',
#   'Published_date': '2021-03-16T11:00:07Z',
#   'Views': '34282',
#   'Likes': '914',
#   'Favourites': '0',
#   'Comments': '53'},
#  {'Title': "Google Data Analytics Professional Certificate | It's Finally Here!",
#   'Published_date': '2021-03-12T12:00:17Z',
#   'Views': '222982',
#   'Likes': '7837',
#   'Favourites': '0',
#   'Comments': '1037'},
#  {'Title': 'Google Data Analytics Certificate | Coming Out Soon!',
#   'Published_date': '2021-03-04T12:15:01Z',
#   'Views': '49326',
#   'Likes': '2342',
#   'Favourites': '0',
#   'Comments': '328'},
#  {'Title': 'Reviewing Your Data Analyst Resumes | Part 2',
#   'Published_date': '2021-03-02T12:00:08Z',
#   'Views': '11485',
#   'Likes': '339',
#   'Favourites': '0',
#   'Comments': '69'},
#  {'Title': 'Best Course to Learn Statistics for Data Analysis',
#   'Published_date': '2021-02-25T12:00:13Z',
#   'Views': '21893',
#   'Likes': '899',
#   'Favourites': '0',
#   'Comments': '66'},
#  {'Title': 'DataQuest Review | Is it Worth it?',
#   'Published_date': '2021-02-23T12:00:19Z',
#   'Views': '9199',
#   'Likes': '225',
#   'Favourites': '0',
#   'Comments': '40'},
#  {'Title': 'R vs Python | Which is Better for Data Analysis?',
#   'Published_date': '2021-02-16T12:00:00Z',
#   'Views': '74596',
#   'Likes': '2049',
#   'Favourites': '0',
#   'Comments': '253'},
#  {'Title': 'Advanced SQL Tutorial | String Functions + Use Cases',
#   'Published_date': '2021-02-04T12:00:04Z',
#   'Views': '15347',
#   'Likes': '485',
#   'Favourites': '0',
#   'Comments': '37'},
#  {'Title': 'Advanced SQL Tutorial | Temp Tables',
#   'Published_date': '2021-02-02T12:00:13Z',
#   'Views': '23951',
#   'Likes': '695',
#   'Favourites': '0',
#   'Comments': '43'},
#  {'Title': 'IBM Data Analyst Certificate Study Session',
#   'Published_date': '2021-01-30T15:33:41Z',
#   'Views': '4540',
#   'Likes': '169',
#   'Favourites': '0',
#   'Comments': '22'},
#  {'Title': 'IBM Data Analyst Professional Certificate by Coursera | Is it Worth it?',
#   'Published_date': '2021-01-26T12:00:22Z',
#   'Views': '48240',
#   'Likes': '1560',
#   'Favourites': '0',
#   'Comments': '241'},
#  {'Title': 'DataCamp Review | Is it Worth it?',
#   'Published_date': '2021-01-21T12:00:03Z',
#   'Views': '54468',
#   'Likes': '1418',
#   'Favourites': '0',
#   'Comments': '177'},
#  {'Title': 'Best Python Course for Data Analysts',
#   'Published_date': '2021-01-19T12:00:09Z',
#   'Views': '18582',
#   'Likes': '729',
#   'Favourites': '0',
#   'Comments': '99'},
#  {'Title': 'Top 5 Data Analyst Skills',
#   'Published_date': '2021-01-12T12:00:07Z',
#   'Views': '15140',
#   'Likes': '891',
#   'Favourites': '0',
#   'Comments': '163'},
#  {'Title': 'Best Industries for Data Analysts in 2021 | Alex The Analyst Show | Episode 17',
#   'Published_date': '2021-01-07T12:00:28Z',
#   'Views': '8602',
#   'Likes': '320',
#   'Favourites': '0',
#   'Comments': '133'},
#  {'Title': 'Top 5 Data Analyst Interview Mistakes',
#   'Published_date': '2021-01-05T12:00:10Z',
#   'Views': '11021',
#   'Likes': '451',
#   'Favourites': '0',
#   'Comments': '51'},
#  {'Title': '2020 Year End Review + Upcoming Giveaway Details',
#   'Published_date': '2020-12-31T12:00:01Z',
#   'Views': '1460',
#   'Likes': '143',
#   'Favourites': '0',
#   'Comments': '101'},
#  {'Title': 'Data Analyst Resume | Everything You Need to Know | Alex The Analyst Show | Episode 16',
#   'Published_date': '2020-12-24T12:00:19Z',
#   'Views': '15355',
#   'Likes': '562',
#   'Favourites': '0',
#   'Comments': '106'},
#  {'Title': 'Solving Medium Level SQL LeetCode Questions | Part 2/3',
#   'Published_date': '2020-12-22T12:00:04Z',
#   'Views': '5115',
#   'Likes': '130',
#   'Favourites': '0',
#   'Comments': '24'},
#  {'Title': 'Entry vs Mid vs Senior Level Data Analyst | Alex The Analyst Show | Episode 15',
#   'Published_date': '2020-12-17T12:00:12Z',
#   'Views': '17177',
#   'Likes': '700',
#   'Favourites': '0',
#   'Comments': '162'},
#  {'Title': 'Data Engineer vs Data Analyst | Which Is Right For You?',
#   'Published_date': '2020-12-15T12:00:08Z',
#   'Views': '19498',
#   'Likes': '835',
#   'Favourites': '0',
#   'Comments': '96'},
#  {'Title': 'How to Find Out Your Coworkers Salary | Alex The Analyst Show | Episode 14',
#   'Published_date': '2020-12-10T12:00:30Z',
#   'Views': '1794',
#   'Likes': '75',
#   'Favourites': '0',
#   'Comments': '51'},
#  {'Title': 'Advanced SQL Tutorial | CTE (Common Table Expression)',
#   'Published_date': '2020-12-08T12:00:05Z',
#   'Views': '37236',
#   'Likes': '736',
#   'Favourites': '0',
#   'Comments': '71'},
#  {'Title': 'Data Analyst Salary (Expectations, Bonuses, 401K, ESPP) | Alex The Analyst Show | Episode 13',
#   'Published_date': '2020-12-03T12:00:00Z',
#   'Views': '11696',
#   'Likes': '449',
#   'Favourites': '0',
#   'Comments': '164'},
#  {'Title': 'Intermediate SQL Tutorial | Partition By',
#   'Published_date': '2020-12-01T12:04:43Z',
#   'Views': '24049',
#   'Likes': '840',
#   'Favourites': '0',
#   'Comments': '81'},
#  {'Title': 'Data Analyst Q/A LIVE #5 | AMA',
#   'Published_date': '2020-11-28T17:07:30Z',
#   'Views': '2478',
#   'Likes': '93',
#   'Favourites': '0',
#   'Comments': '21'},
#  {'Title': 'Completely REALISTIC Jobs on LinkedIn | Alex The Analyst Show | Episode 11',
#   'Published_date': '2020-11-25T11:00:05Z',
#   'Views': '10576',
#   'Likes': '460',
#   'Favourites': '0',
#   'Comments': '134'},
#  {'Title': 'Completely Unrealistic Jobs on LinkedIn | Alex The Analyst Show | Episode 11',
#   'Published_date': '2020-11-19T15:00:26Z',
#   'Views': '7786',
#   'Likes': '341',
#   'Favourites': '0',
#   'Comments': '176'},
#  {'Title': 'Top 3 Tips on Using LinkedIn to Land a Job',
#   'Published_date': '2020-11-17T14:11:52Z',
#   'Views': '29501',
#   'Likes': '1741',
#   'Favourites': '0',
#   'Comments': '112'},
#  {'Title': 'What is No Code Analytics? | Alex The Analyst Show | Episode #9',
#   'Published_date': '2020-11-12T12:34:08Z',
#   'Views': '2686',
#   'Likes': '102',
#   'Favourites': '0',
#   'Comments': '73'},
#  {'Title': 'Solving LeetCode SQL Interview Questions | Part 1/3',
#   'Published_date': '2020-11-10T15:02:50Z',
#   'Views': '11242',
#   'Likes': '349',
#   'Favourites': '0',
#   'Comments': '57'},
#  {'Title': 'What is Analytics Consulting? With John Ariansen | Alex The Analyst Show | Episode 9',
#   'Published_date': '2020-11-05T15:43:17Z',
#   'Views': '5311',
#   'Likes': '202',
#   'Favourites': '0',
#   'Comments': '93'},
#  {'Title': 'Data Analyst Skills Path | What Skills You NEED to Know',
#   'Published_date': '2020-11-03T15:13:12Z',
#   'Views': '36656',
#   'Likes': '2100',
#   'Favourites': '0',
#   'Comments': '251'},
#  {'Title': 'Data Analyst Q&A LIVE #4',
#   'Published_date': '2020-10-30T15:13:53Z',
#   'Views': '2814',
#   'Likes': '92',
#   'Favourites': '0',
#   'Comments': '25'},
#  {'Title': 'Asking My Wife Your Questions About Me | Alex The Analyst Show | Episode 8',
#   'Published_date': '2020-10-27T16:06:53Z',
#   'Views': '8005',
#   'Likes': '360',
#   'Favourites': '0',
#   'Comments': '177'},
#  {'Title': 'Top 10 Udemy Courses for Data Analysts',
#   'Published_date': '2020-10-22T15:14:21Z',
#   'Views': '54588',
#   'Likes': '2175',
#   'Favourites': '0',
#   'Comments': '237'},
#  {'Title': 'Data Analyst Certifications | Are They Worth It? | Alex The Analyst Show | Episode 7',
#   'Published_date': '2020-10-20T14:08:32Z',
#   'Views': '92386',
#   'Likes': '3637',
#   'Favourites': '0',
#   'Comments': '777'},
#  {'Title': 'Working at a Startup vs Fortune 500 Company | Alex The Analyst Show | Episode 6',
#   'Published_date': '2020-10-15T15:33:32Z',
#   'Views': '2500',
#   'Likes': '131',
#   'Favourites': '0',
#   'Comments': '63'},
#  {'Title': 'Top 10 Coursera Courses for Data Analysts',
#   'Published_date': '2020-10-13T14:40:18Z',
#   'Views': '53895',
#   'Likes': '2975',
#   'Favourites': '0',
#   'Comments': '247'},
#  {'Title': 'Imposter Syndrome in Tech | Alex The Analyst Show | Episode 5',
#   'Published_date': '2020-10-08T14:26:27Z',
#   'Views': '4294',
#   'Likes': '247',
#   'Favourites': '0',
#   'Comments': '164'},
#  {'Title': 'Data Analyst Expectations vs Reality',
#   'Published_date': '2020-10-06T14:52:33Z',
#   'Views': '71139',
#   'Likes': '2689',
#   'Favourites': '0',
#   'Comments': '194'},
#  {'Title': 'Covid and the Data Analyst Job Market | Alex The Analyst Show | Episode 4',
#   'Published_date': '2020-10-01T13:53:17Z',
#   'Views': '5702',
#   'Likes': '229',
#   'Favourites': '0',
#   'Comments': '159'},
#  {'Title': 'Self Taught vs Boot Camp vs Degree | Alex The Analyst Show | Episode 3',
#   'Published_date': '2020-09-24T15:29:17Z',
#   'Views': '16897',
#   'Likes': '674',
#   'Favourites': '0',
#   'Comments': '461'},
#  {'Title': "Top 5 Reasons You'll Be a Good Data Analyst",
#   'Published_date': '2020-09-22T13:03:29Z',
#   'Views': '9304',
#   'Likes': '467',
#   'Favourites': '0',
#   'Comments': '81'},
#  {'Title': 'How I Changed Careers to Become a Data Analyst | Alex The Analyst Show | Episode 2',
#   'Published_date': '2020-09-10T13:16:00Z',
#   'Views': '202630',
#   'Likes': '6653',
#   'Favourites': '0',
#   'Comments': '2375'},
#  {'Title': 'Top 5 Reasons Data Analytics is a Good Career Choice',
#   'Published_date': '2020-09-08T14:15:55Z',
#   'Views': '17548',
#   'Likes': '673',
#   'Favourites': '0',
#   'Comments': '55'},
#  {'Title': "The Hiring Process from an Interviewer's Perspective | Alex The Analyst Show | Episode 1",
#   'Published_date': '2020-09-03T15:38:28Z',
#   'Views': '7859',
#   'Likes': '339',
#   'Favourites': '0',
#   'Comments': '74'},
#  {'Title': 'Top 5 Reasons Not to Lie on Your Resume',
#   'Published_date': '2020-09-01T12:29:45Z',
#   'Views': '6488',
#   'Likes': '135',
#   'Favourites': '0',
#   'Comments': '69'},
#  {'Title': 'Live Data Analyst Q&A #3',
#   'Published_date': '2020-08-29T14:37:52Z',
#   'Views': '1945',
#   'Likes': '82',
#   'Favourites': '0',
#   'Comments': '43'},
#  {'Title': 'Data Analyst Career Path | How to Become a Data Analyst + What to Do Next',
#   'Published_date': '2020-08-20T13:46:16Z',
#   'Views': '91805',
#   'Likes': '3556',
#   'Favourites': '0',
#   'Comments': '265'},
#  {'Title': 'Top 5 Reasons Not to Become a Data Analyst',
#   'Published_date': '2020-08-12T14:52:19Z',
#   'Views': '463065',
#   'Likes': '10406',
#   'Favourites': '0',
#   'Comments': '815'},
#  {'Title': 'Data Analyst Bootcamps | Are They Worth It?',
#   'Published_date': '2020-08-05T13:14:01Z',
#   'Views': '13400',
#   'Likes': '283',
#   'Favourites': '0',
#   'Comments': '74'},
#  {'Title': 'What Does a Data Analyst Actually Do?',
#   'Published_date': '2020-07-29T13:48:00Z',
#   'Views': '248607',
#   'Likes': '5848',
#   'Favourites': '0',
#   'Comments': '278'},
#  {'Title': 'Data Analyst Question and Answer | Answering Your YouTube Questions',
#   'Published_date': '2020-07-22T14:35:55Z',
#   'Views': '2684',
#   'Likes': '135',
#   'Favourites': '0',
#   'Comments': '64'},
#  {'Title': 'Scraping Data Off Twitter Using Python | Twitterscraper + NLP + Data Visualization',
#   'Published_date': '2020-07-15T14:00:20Z',
#   'Views': '29285',
#   'Likes': '836',
#   'Favourites': '0',
#   'Comments': '147'},
#  {'Title': 'Data Analyst vs Business Analyst | Which Is Right For You?',
#   'Published_date': '2020-07-03T14:17:52Z',
#   'Views': '385601',
#   'Likes': '10566',
#   'Favourites': '0',
#   'Comments': '469'},
#  {'Title': 'Best Free Online Courses for Data Analysts',
#   'Published_date': '2020-06-23T13:55:50Z',
#   'Views': '32908',
#   'Likes': '1895',
#   'Favourites': '0',
#   'Comments': '86'},
#  {'Title': 'Best Online Courses for Data Analysts',
#   'Published_date': '2020-06-17T14:57:22Z',
#   'Views': '115675',
#   'Likes': '6448',
#   'Favourites': '0',
#   'Comments': '367'},
#  {'Title': 'Data Scientist vs Data Analyst | Which Is Right For You?',
#   'Published_date': '2020-06-10T15:49:15Z',
#   'Views': '436586',
#   'Likes': '14291',
#   'Favourites': '0',
#   'Comments': '669'},
#  {'Title': 'Intermediate SQL Tutorial | Aliasing',
#   'Published_date': '2020-06-04T14:00:10Z',
#   'Views': '11140',
#   'Likes': '407',
#   'Favourites': '0',
#   'Comments': '31'},
#  {'Title': 'Data Analyst Q&A LIVE',
#   'Published_date': '2020-05-31T13:54:38Z',
#   'Views': '4785',
#   'Likes': '160',
#   'Favourites': '0',
#   'Comments': '53'},
#  {'Title': 'Data Analyst Interviews | Salary Negotiation',
#   'Published_date': '2020-05-27T15:13:50Z',
#   'Views': '8480',
#   'Likes': '320',
#   'Favourites': '0',
#   'Comments': '22'},
#  {'Title': 'Data Analyst Interview Questions | What To Say vs What NOT To Say',
#   'Published_date': '2020-05-20T14:03:02Z',
#   'Views': '17819',
#   'Likes': '571',
#   'Favourites': '0',
#   'Comments': '18'},
#  {'Title': 'SQL Interview Questions and Answers for Beginners | Data Analyst Interview Questions',
#   'Published_date': '2020-05-13T15:00:26Z',
#   'Views': '45861',
#   'Likes': '1339',
#   'Favourites': '0',
#   'Comments': '76'},
#  {'Title': 'Data Analyst Interview Questions | Phone + In-Person Interview Questions',
#   'Published_date': '2020-05-06T15:20:18Z',
#   'Views': '26377',
#   'Likes': '630',
#   'Favourites': '0',
#   'Comments': '46'},
#  {'Title': 'Day in the Life of a Data Analyst | Fortune 500 Edition (During Quarantine)',
#   'Published_date': '2020-04-23T13:08:33Z',
#   'Views': '11581',
#   'Likes': '404',
#   'Favourites': '0',
#   'Comments': '48'},
#  {'Title': 'Intermediate SQL Tutorial | Updating/Deleting Data',
#   'Published_date': '2020-04-16T12:58:52Z',
#   'Views': '11058',
#   'Likes': '358',
#   'Favourites': '0',
#   'Comments': '37'},
#  {'Title': 'Intermediate SQL Tutorial | Having Clause',
#   'Published_date': '2020-04-09T16:01:02Z',
#   'Views': '13320',
#   'Likes': '478',
#   'Favourites': '0',
#   'Comments': '16'},
#  {'Title': 'Intermediate SQL Tutorial | Case Statement | Use Cases',
#   'Published_date': '2020-04-02T15:16:37Z',
#   'Views': '29918',
#   'Likes': '934',
#   'Favourites': '0',
#   'Comments': '107'},
#  {'Title': 'Intermediate SQL Tutorial | Unions | Union Operator',
#   'Published_date': '2020-03-26T16:51:37Z',
#   'Views': '23146',
#   'Likes': '609',
#   'Favourites': '0',
#   'Comments': '32'},
#  {'Title': 'Intermediate SQL Tutorial | Inner/Outer Joins | Use Cases',
#   'Published_date': '2020-03-19T15:40:58Z',
#   'Views': '46704',
#   'Likes': '1099',
#   'Favourites': '0',
#   'Comments': '94'},
#  {'Title': 'Day in the Life of a Data Analyst | Fortune 500 Edition',
#   'Published_date': '2020-03-11T13:44:54Z',
#   'Views': '99729',
#   'Likes': '2037',
#   'Favourites': '0',
#   'Comments': '257'},
#  {'Title': 'SQL Basics Tutorial For Beginners | Group By + Order By Statements | 4/4',
#   'Published_date': '2020-03-03T15:06:36Z',
#   'Views': '25074',
#   'Likes': '998',
#   'Favourites': '0',
#   'Comments': '77'},
#  {'Title': 'SQL Basics Tutorial For Beginners | Where Statement | 3/4',
#   'Published_date': '2020-03-02T16:01:01Z',
#   'Views': '26767',
#   'Likes': '719',
#   'Favourites': '0',
#   'Comments': '33'},
#  {'Title': 'SQL Basics Tutorial For Beginners | Select + From Statements | 2/4',
#   'Published_date': '2020-03-01T17:02:28Z',
#   'Views': '40446',
#   'Likes': '861',
#   'Favourites': '0',
#   'Comments': '45'},
#  {'Title': 'SQL Basics Tutorial For Beginners | Installing SQL Server Management Studio and Create Tables | 1/4',
#   'Published_date': '2020-03-01T00:50:38Z',
#   'Views': '153807',
#   'Likes': '2849',
#   'Favourites': '0',
#   'Comments': '256'},
#  {'Title': 'Data Analyst Fact Check |  84k Average Starting Salary?? | The Career Force 2020 Data Analyst Salary',
#   'Published_date': '2020-02-26T15:11:22Z',
#   'Views': '15096',
#   'Likes': '579',
#   'Favourites': '0',
#   'Comments': '141'},
#  {'Title': 'Data Analyst Resume | Reviewing YOUR Data Analyst Resumes!',
#   'Published_date': '2020-02-24T16:34:51Z',
#   'Views': '11257',
#   'Likes': '288',
#   'Favourites': '0',
#   'Comments': '42'},
#  {'Title': 'Data Analyst Salary in 2020',
#   'Published_date': '2020-02-19T15:43:59Z',
#   'Views': '6286',
#   'Likes': '119',
#   'Favourites': '0',
#   'Comments': '19'},
#  {'Title': 'Working With a Recruiter to Land Your First Job as a Data Analyst | LinkedIn Recruiters',
#   'Published_date': '2020-02-14T18:03:34Z',
#   'Views': '5117',
#   'Likes': '251',
#   'Favourites': '0',
#   'Comments': '34'},
#  {'Title': 'Switching Careers to Become a Data Analyst | How I Made the Switch',
#   'Published_date': '2020-02-11T15:03:18Z',
#   'Views': '36507',
#   'Likes': '1377',
#   'Favourites': '0',
#   'Comments': '240'},
#  {'Title': 'Data Analyst Resume | Complete Guide To Creating A Data Analyst Resume | Tips + Templates + Examples',
#   'Published_date': '2020-02-06T16:00:52Z',
#   'Views': '37805',
#   'Likes': '1358',
#   'Favourites': '0',
#   'Comments': '56'},
#  {'Title': 'Data Analyst Resume | Reviewing My Resume! | Fortune 500 Data Analyst',
#   'Published_date': '2020-01-30T14:07:55Z',
#   'Views': '35124',
#   'Likes': '996',
#   'Favourites': '0',
#   'Comments': '59'},
#  {'Title': 'Working at a Big Company Vs Small Company | Told by a Fortune 500 Data Analyst',
#   'Published_date': '2020-01-25T16:38:39Z',
#   'Views': '6601',
#   'Likes': '207',
#   'Favourites': '0',
#   'Comments': '11'},
#  {'Title': 'Data Analyst Salary | 100k with No Experience',
#   'Published_date': '2020-01-23T03:16:09Z',
#   'Views': '40690',
#   'Likes': '1540',
#   'Favourites': '0',
#   'Comments': '203'},
#  {'Title': 'Truth About Big Companies | Told by a Fortune 500 Data Analyst',
#   'Published_date': '2020-01-21T03:52:15Z',
#   'Views': '4457',
#   'Likes': '175',
#   'Favourites': '0',
#   'Comments': '16'},
#  {'Title': 'Top 3 Data Analyst Skills in 2020',
#   'Published_date': '2020-01-17T14:31:39Z',
#   'Views': '20295',
#   'Likes': '1045',
#   'Favourites': '0',
#   'Comments': '144'}]

# %%
video_details=get_video_name(youtube, video_ids)

# %%
video_data=pd.DataFrame(video_details)

# %%
video_data
# Out:
#                                                  Title        Published_date  \
# 0    Pivot Tables in Excel | Excel Tutorials for Be...  2021-12-14T11:30:07Z
# 1    Tableau Tutorial for Beginners | Full Project ...  2021-12-07T11:30:11Z
# 2    Tableau Tutorial for Beginners | Joins | Part 4/5  2021-11-23T11:30:02Z
# 3            Top 5 Major Red Flags in Job Descriptions  2021-11-18T11:30:08Z
# 4        Truth About My Job (Song) - As a Data Analyst  2021-11-08T11:30:01Z
# ..                                                 ...                   ...
# 116  Data Analyst Resume | Reviewing My Resume! | F...  2020-01-30T14:07:55Z
# 117  Working at a Big Company Vs Small Company | To...  2020-01-25T16:38:39Z
# 118      Data Analyst Salary | 100k with No Experience  2020-01-23T03:16:09Z
# 119  Truth About Big Companies | Told by a Fortune ...  2020-01-21T03:52:15Z
# 120                  Top 3 Data Analyst Skills in 2020  2020-01-17T14:31:39Z
#
#      Views Likes Favourites Comments
# 0     7574   389          0       45
# 1     6632   156          0       26
# 2     5436   160          0       14
# 3     9255   561          0       58
# 4     6940   657          0       90
# ..     ...   ...        ...      ...
# 116  35124   996          0       59
# 117   6601   207          0       11
# 118  40690  1540          0      203
# 119   4457   175          0       16
# 120  20295  1045          0      144
#
# [121 rows x 6 columns]

# %%
#change the data types for visualization
video_data['Published_date']=pd.to_datetime(video_data['Published_date']).dt.date
video_data['Views']=pd.to_numeric(video_data['Views'])
video_data['Likes']=pd.to_numeric(video_data['Likes'])
video_data['Favourites']=pd.to_numeric(video_data['Favourites'])
video_data['Comments']=pd.to_numeric(video_data['Comments'])
video_data
# Out:
#                                                  Title Published_date  Views  \
# 0    Pivot Tables in Excel | Excel Tutorials for Be...     2021-12-14   7574
# 1    Tableau Tutorial for Beginners | Full Project ...     2021-12-07   6632
# 2    Tableau Tutorial for Beginners | Joins | Part 4/5     2021-11-23   5436
# 3            Top 5 Major Red Flags in Job Descriptions     2021-11-18   9255
# 4        Truth About My Job (Song) - As a Data Analyst     2021-11-08   6940
# ..                                                 ...            ...    ...
# 116  Data Analyst Resume | Reviewing My Resume! | F...     2020-01-30  35124
# 117  Working at a Big Company Vs Small Company | To...     2020-01-25   6601
# 118      Data Analyst Salary | 100k with No Experience     2020-01-23  40690
# 119  Truth About Big Companies | Told by a Fortune ...     2020-01-21   4457
# 120                  Top 3 Data Analyst Skills in 2020     2020-01-17  20295
#
#      Likes  Favourites  Comments
# 0      389           0        45
# 1      156           0        26
# 2      160           0        14
# 3      561           0        58
# 4      657           0        90
# ..     ...         ...       ...
# 116    996           0        59
# 117    207           0        11
# 118   1540           0       203
# 119    175           0        16
# 120   1045           0       144
#
# [121 rows x 6 columns]

# %%
video_data.dtypes
# Out:
# Title             object
# Published_date    object
# Views              int64
# Likes              int64
# Favourites         int64
# Comments           int64
# dtype: object

# %%
# Get the top videos based on views
top_ten_videos=video_data.sort_values(by='Views',ascending=False).head(10)
top_ten_videos
# Out:
#                                                  Title Published_date   Views  \
# 84          Top 5 Reasons Not to Become a Data Analyst     2020-08-12  463065
# 92   Data Scientist vs Data Analyst | Which Is Righ...     2020-06-10  436586
# 89   Data Analyst vs Business Analyst | Which Is Ri...     2020-07-03  385601
# 26   Data Analyst Portfolio Project | SQL Data Expl...     2021-05-04  275236
# 86               What Does a Data Analyst Actually Do?     2020-07-29  248607
# 35   Google Data Analytics Professional Certificate...     2021-03-12  222984
# 78   How I Changed Careers to Become a Data Analyst...     2020-09-10  202630
# 20   How To Get a Data Analyst Job (with No Experie...     2021-06-08  165198
# 109  SQL Basics Tutorial For Beginners | Installing...     2020-03-01  153807
# 17   Why You Need to Stop Taking Courses (From an E...     2021-07-13  119225
#
#      Likes  Favourites  Comments
# 84   10406           0       815
# 92   14291           0       669
# 89   10566           0       469
# 26    7666           0       945
# 86    5848           0       278
# 35    7837           0      1037
# 78    6653           0      2375
# 20    8378           0       427
# 109   2849           0       256
# 17    5161           0       360

# %%
#visualize the data
ax1=sns.barplot(x='Views', y='Title', data=top_ten_videos)

# %%
# Group the videos by month 
#Add a new column of month
video_data['Month']=pd.to_datetime(video_data['Published_date']).dt.strftime('%b')
video_data
# Out:
#                                                  Title Published_date  Views  \
# 0    Pivot Tables in Excel | Excel Tutorials for Be...     2021-12-14   7574
# 1    Tableau Tutorial for Beginners | Full Project ...     2021-12-07   6632
# 2    Tableau Tutorial for Beginners | Joins | Part 4/5     2021-11-23   5436
# 3            Top 5 Major Red Flags in Job Descriptions     2021-11-18   9255
# 4        Truth About My Job (Song) - As a Data Analyst     2021-11-08   6940
# ..                                                 ...            ...    ...
# 116  Data Analyst Resume | Reviewing My Resume! | F...     2020-01-30  35124
# 117  Working at a Big Company Vs Small Company | To...     2020-01-25   6601
# 118      Data Analyst Salary | 100k with No Experience     2020-01-23  40690
# 119  Truth About Big Companies | Told by a Fortune ...     2020-01-21   4457
# 120                  Top 3 Data Analyst Skills in 2020     2020-01-17  20295
#
#      Likes  Favourites  Comments Month
# 0      389           0        45   Dec
# 1      156           0        26   Dec
# 2      160           0        14   Nov
# 3      561           0        58   Nov
# 4      657           0        90   Nov
# ..     ...         ...       ...   ...
# 116    996           0        59   Jan
# 117    207           0        11   Jan
# 118   1540           0       203   Jan
# 119    175           0        16   Jan
# 120   1045           0       144   Jan
#
# [121 rows x 7 columns]

# %%
uploaded_video_per_month=video_data.groupby('Month', as_index=False).size()
uploaded_video_per_month
# Out:
#    Month  size
# 0    Apr     8
# 1    Aug     9
# 2    Dec    11
# 3    Feb    11
# 4    Jan    12
# 5    Jul     6
# 6    Jun     9
# 7    Mar    14
# 8    May     9
# 9    Nov    11
# 10   Oct    12
# 11   Sep     9

# %%
sort_order=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

# %%
uploaded_video_per_month.index=pd.CategoricalIndex(uploaded_video_per_month['Month'], categories=sort_order, ordered=True)

# %%
uploaded_video_per_month=uploaded_video_per_month.sort_index()

# %%
ax2=sns.barplot(x='Month',y='size',data=uploaded_video_per_month)
